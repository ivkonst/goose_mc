# %%
# !head -2 ../data/site_soup_prohiphop.jsonl
# Out:
# {"link": "prohiphop.org", "soup": [["html", "text", "[document]:1"], ["Хип Хоп портал ProHipHop.org", "text", "[document]:1>html:2>head:1>title:6"], ["ProHipHop.org", "text", "header:2>div:2>div:2>div:2>h2:2>a:1"], ["Регистрация", "text", "nav:4>div:5>ul:2>li:2>a:2"], ["Вход", "text", "nav:4>div:5>ul:2>li:4>a:2"], ["Альбомы", "text", "nav:4>div:5>ul:2>li:6>a:2"], ["Клипы", "text", "nav:4>div:5>ul:2>li:8>a:2"], ["Биографии", "text", "nav:4>div:5>ul:2>li:10>a:2"], ["Видео", "text", "nav:4>div:5>ul:2>li:12>a:2"], ["Минуса", "text", "nav:4>div:5>ul:2>li:14>a:2"], ["Концерты", "text", "nav:4>div:5>ul:2>li:16>a:2"], ["Батлы", "text", "nav:4>div:5>ul:2>li:18>a:2"], ["Versus", "text", "nav:4>div:5>ul:2>li:18>div:4>a:2"], ["Slovo", "text", "nav:4>div:5>ul:2>li:18>div:4>a:4"], ["Тексты", "text", "nav:4>div:5>ul:2>li:20>a:2"], ["Тексты исполнителей", "text", "nav:4>div:5>ul:2>li:20>div:4>a:2"], ["Тексты пользователей", "text", "nav:4>div:5>ul:2>li:20>div:4>a:4"], ["Рэп тексты известных рэперов"
# ...
